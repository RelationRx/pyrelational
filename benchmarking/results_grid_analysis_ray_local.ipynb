# %%
import os
import sys
import pandas as pd
import seaborn as sns

# %% [markdown]
# # Results grid analysis notebook
#
# Running the trials and experiments via Ray produces a number of files that are related to the "experiment" (dataset and all the strategies + all the repeated runs, each being a "trial"). Each trial is stored individually, but will be read and collected by a `result_grid` object that can be used to analyse results at the experiment and trial level.
#
# This notebook is intended to be used for all the experiments, adapt as necessary to produce the relevant plots.

# %%
# Load result_grid
# Adapt as needed
from ray import tune
experiment_name = "airfoil"
storage_path = os.path.join(os.getcwd(), f"ray_benchmark_results")
experiment_path = os.path.join(storage_path, experiment_name)

print(f"Loading results from {experiment_path}...")

restored_tuner = tune.Tuner.restore(experiment_path, trainable="trial")
result_grid = restored_tuner.get_results()
print(f"Type of result_grid: {type(result_grid)}")
# Out:
# Loading results from /Users/rlps281/workspace/pyrelational/benchmarking/ray_benchmark_results/airfoil...
# Type of result_grid: <class 'ray.tune.result_grid.ResultGrid'>

# %%
# First we will do some housekeeping to make sure our results grid is as we expect

# Check if there have been errors
if result_grid.errors:
    print("One of the trials failed!")
else:
    print("No errors!")

num_results = len(result_grid)
print("Number of results:", num_results)

# Iterate over results
for i, result in enumerate(result_grid):
    if result.error:
        print(f"Trial #{i} had an error:", result.error)
        continue

    print(
        f"Trial #{i} finished successfully with a test metric of: {result.metrics["score"]}"
    )
# Out:
# One of the trials failed!
# Number of results: 35
# Trial #0 finished successfully with a test metric of: 5166459.1522663105
# Trial #1 finished successfully with a test metric of: 7043507.057155893
# Trial #2 finished successfully with a test metric of: 5745135.180333761
# Trial #3 finished successfully with a test metric of: 5613696.011379477
# Trial #4 finished successfully with a test metric of: 7681065.292890332
# Trial #5 finished successfully with a test metric of: 7052488.507552644
# Trial #6 finished successfully with a test metric of: 7929654.11983299
# Trial #7 finished successfully with a test metric of: 4554841.71315625
# Trial #8 finished successfully with a test metric of: 7594551.161501663
# Trial #9 finished successfully with a test metric of: 5233231.865834427
# Trial #10 finished successfully with a test metric of: 5683197.612792347
# Trial #11 finished successfully with a test metric of: 5566090.485449876
# Trial #12 finished successfully with a test metric of: 7648742.795624595
# Trial #13 had an error: ray::ImplicitFunc.train() (pid=48762, ip=127.0.0.1, actor_id=dba57c96d6604d2aa4c7ca8c01000000, repr=trial)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rlps281/miniconda3/envs/pyrelational/lib/python3.12/site-packages/ray/tune/trainable/trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "/Users/rlps281/miniconda3/envs/pyrelational/lib/python3.12/site-packages/ray/air/_internal/util.py", line 98, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rlps281/miniconda3/envs/pyrelational/lib/python3.12/site-packages/ray/tune/trainable/function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rlps281/miniconda3/envs/pyrelational/lib/python3.12/site-packages/ray/tune/trainable/function_trainable.py", line 250, in _trainable_func
#     output = fn()
#              ^^^^
#   File "/Users/rlps281/workspace/pyrelational/benchmarking/airfoil.py", line 56, in trial
#     pipeline.run(num_annotate=1)
#   File "/Users/rlps281/workspace/pyrelational/pyrelational/pipeline/pipeline.py", line 191, in run
#     observations_for_labelling = self.step(num_annotate, *strategy_args, **strategy_kwargs)
#                                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rlps281/workspace/pyrelational/pyrelational/pipeline/pipeline.py", line 147, in step
#     observations_for_labelling = self.strategy.suggest(num_annotate, *args, **kwargs)
#                                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rlps281/workspace/pyrelational/pyrelational/strategies/abstract_strategy.py", line 76, in suggest
#     return self(num_annotate=num_annotate, **filtered_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rlps281/workspace/pyrelational/pyrelational/strategies/regression/regression_strategy.py", line 29, in __call__
#     output = self.train_and_infer(data_manager=data_manager, model_manager=model_manager)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rlps281/workspace/pyrelational/pyrelational/strategies/abstract_strategy.py", line 91, in train_and_infer
#     output = model_manager(data_manager.get_unlabelled_loader())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rlps281/workspace/pyrelational/benchmarking/regression_experiment_utils.py", line 100, in __call__
#     class_probabilities = model.sample_y(X, n_samples=10)
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rlps281/miniconda3/envs/pyrelational/lib/python3.12/site-packages/sklearn/gaussian_process/_gpr.py", line 522, in sample_y
#     y_samples = rng.multivariate_normal(y_mean, y_cov, n_samples).T
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "numpy/random/mtrand.pyx", line 4236, in numpy.random.mtrand.RandomState.multivariate_normal
#   File "/Users/rlps281/miniconda3/envs/pyrelational/lib/python3.12/site-packages/numpy/linalg/linalg.py", line 1681, in svd
#     u, s, vh = gufunc(a, signature=signature, extobj=extobj)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rlps281/miniconda3/envs/pyrelational/lib/python3.12/site-packages/numpy/linalg/linalg.py", line 121, in _raise_linalgerror_svd_nonconvergence
#     raise LinAlgError("SVD did not converge")
# numpy.linalg.LinAlgError: SVD did not converge
# Trial #14 finished successfully with a test metric of: 5851131.8579760585
# Trial #15 finished successfully with a test metric of: 4554841.33856356
# Trial #16 finished successfully with a test metric of: 4301750.13111392
# Trial #17 finished successfully with a test metric of: 7516239.274592567
# Trial #18 finished successfully with a test metric of: 4751765.248839273
# Trial #19 finished successfully with a test metric of: 4301719.516950268
# Trial #20 finished successfully with a test metric of: 5625434.802925259
# Trial #21 finished successfully with a test metric of: 6015328.01936519
# Trial #22 finished successfully with a test metric of: 4849121.057410052
# Trial #23 finished successfully with a test metric of: 7543685.141891564
# Trial #24 finished successfully with a test metric of: 5522924.652447792
# Trial #25 finished successfully with a test metric of: 7903642.281391344
# Trial #26 finished successfully with a test metric of: 5596055.252932846
# Trial #27 finished successfully with a test metric of: 7644219.912131105
# Trial #28 finished successfully with a test metric of: 4848534.901611669
# Trial #29 finished successfully with a test metric of: 4751770.097356993
# Trial #30 finished successfully with a test metric of: 5400356.419960866
# Trial #31 finished successfully with a test metric of: 5671708.433803733
# Trial #32 finished successfully with a test metric of: 5610503.756292498
# Trial #33 had an error: ray::ImplicitFunc.train() (pid=45769, ip=127.0.0.1, actor_id=55499bd10e80f4be53aa1d3401000000, repr=trial)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rlps281/miniconda3/envs/pyrelational/lib/python3.12/site-packages/ray/tune/trainable/trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "/Users/rlps281/miniconda3/envs/pyrelational/lib/python3.12/site-packages/ray/air/_internal/util.py", line 98, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rlps281/miniconda3/envs/pyrelational/lib/python3.12/site-packages/ray/tune/trainable/function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rlps281/miniconda3/envs/pyrelational/lib/python3.12/site-packages/ray/tune/trainable/function_trainable.py", line 250, in _trainable_func
#     output = fn()
#              ^^^^
#   File "/Users/rlps281/workspace/pyrelational/benchmarking/airfoil.py", line 56, in trial
#     pipeline.run(num_annotate=1)
#   File "/Users/rlps281/workspace/pyrelational/pyrelational/pipeline/pipeline.py", line 191, in run
#     observations_for_labelling = self.step(num_annotate, *strategy_args, **strategy_kwargs)
#                                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rlps281/workspace/pyrelational/pyrelational/pipeline/pipeline.py", line 147, in step
#     observations_for_labelling = self.strategy.suggest(num_annotate, *args, **kwargs)
#                                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rlps281/workspace/pyrelational/pyrelational/strategies/abstract_strategy.py", line 76, in suggest
#     return self(num_annotate=num_annotate, **filtered_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rlps281/workspace/pyrelational/pyrelational/strategies/regression/regression_strategy.py", line 29, in __call__
#     output = self.train_and_infer(data_manager=data_manager, model_manager=model_manager)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rlps281/workspace/pyrelational/pyrelational/strategies/abstract_strategy.py", line 91, in train_and_infer
#     output = model_manager(data_manager.get_unlabelled_loader())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rlps281/workspace/pyrelational/benchmarking/regression_experiment_utils.py", line 100, in __call__
#     class_probabilities = model.sample_y(X, n_samples=10)
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rlps281/miniconda3/envs/pyrelational/lib/python3.12/site-packages/sklearn/gaussian_process/_gpr.py", line 522, in sample_y
#     y_samples = rng.multivariate_normal(y_mean, y_cov, n_samples).T
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "numpy/random/mtrand.pyx", line 4236, in numpy.random.mtrand.RandomState.multivariate_normal
#   File "/Users/rlps281/miniconda3/envs/pyrelational/lib/python3.12/site-packages/numpy/linalg/linalg.py", line 1681, in svd
#     u, s, vh = gufunc(a, signature=signature, extobj=extobj)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rlps281/miniconda3/envs/pyrelational/lib/python3.12/site-packages/numpy/linalg/linalg.py", line 121, in _raise_linalgerror_svd_nonconvergence
#     raise LinAlgError("SVD did not converge")
# numpy.linalg.LinAlgError: SVD did not converge
# Trial #34 had an error: ray::ImplicitFunc.train() (pid=46284, ip=127.0.0.1, actor_id=6703998f6fb8dab31d7fcd3c01000000, repr=trial)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rlps281/miniconda3/envs/pyrelational/lib/python3.12/site-packages/ray/tune/trainable/trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "/Users/rlps281/miniconda3/envs/pyrelational/lib/python3.12/site-packages/ray/air/_internal/util.py", line 98, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rlps281/miniconda3/envs/pyrelational/lib/python3.12/site-packages/ray/tune/trainable/function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rlps281/miniconda3/envs/pyrelational/lib/python3.12/site-packages/ray/tune/trainable/function_trainable.py", line 250, in _trainable_func
#     output = fn()
#              ^^^^
#   File "/Users/rlps281/workspace/pyrelational/benchmarking/airfoil.py", line 56, in trial
#     pipeline.run(num_annotate=1)
#   File "/Users/rlps281/workspace/pyrelational/pyrelational/pipeline/pipeline.py", line 191, in run
#     observations_for_labelling = self.step(num_annotate, *strategy_args, **strategy_kwargs)
#                                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rlps281/workspace/pyrelational/pyrelational/pipeline/pipeline.py", line 147, in step
#     observations_for_labelling = self.strategy.suggest(num_annotate, *args, **kwargs)
#                                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rlps281/workspace/pyrelational/pyrelational/strategies/abstract_strategy.py", line 76, in suggest
#     return self(num_annotate=num_annotate, **filtered_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rlps281/workspace/pyrelational/pyrelational/strategies/regression/expected_improvement_strategy.py", line 42, in __call__
#     output = self.train_and_infer(data_manager=data_manager, model_manager=model_manager)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rlps281/workspace/pyrelational/pyrelational/strategies/abstract_strategy.py", line 91, in train_and_infer
#     output = model_manager(data_manager.get_unlabelled_loader())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rlps281/workspace/pyrelational/benchmarking/regression_experiment_utils.py", line 100, in __call__
#     class_probabilities = model.sample_y(X, n_samples=10)
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rlps281/miniconda3/envs/pyrelational/lib/python3.12/site-packages/sklearn/gaussian_process/_gpr.py", line 522, in sample_y
#     y_samples = rng.multivariate_normal(y_mean, y_cov, n_samples).T
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "numpy/random/mtrand.pyx", line 4236, in numpy.random.mtrand.RandomState.multivariate_normal
#   File "/Users/rlps281/miniconda3/envs/pyrelational/lib/python3.12/site-packages/numpy/linalg/linalg.py", line 1681, in svd
#     u, s, vh = gufunc(a, signature=signature, extobj=extobj)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rlps281/miniconda3/envs/pyrelational/lib/python3.12/site-packages/numpy/linalg/linalg.py", line 121, in _raise_linalgerror_svd_nonconvergence
#     raise LinAlgError("SVD did not converge")
# numpy.linalg.LinAlgError: SVD did not converge

# %%
results_df = result_grid.get_dataframe()

# %%
results_df
# Out:
#            score                                  iteration_metrics  \
# 0   5.166459e+06  [12543.135440504588, 12544.588570068567, 12502...
# 1   7.043507e+06  [12543.135440504588, 12540.191182303699, 12535...
# 2   5.745135e+06  [12486.163329241215, 12485.950789931872, 12485...
# 3   5.613696e+06  [12499.060638330988, 12494.97070996466, 12462....
# 4   7.681065e+06  [12499.060638330988, 12499.063827674741, 12499...
# 5   7.052489e+06  [12543.135440504588, 12540.191182303699, 12535...
# 6   7.929654e+06  [12833.385861673749, 12833.385455500184, 12835...
# 7   4.554842e+06  [12833.385861673749, 12831.358653723166, 12822...
# 8   7.594551e+06  [12486.163329241215, 12481.868142346457, 12481...
# 9   5.233232e+06  [12543.135440504588, 12468.427091261497, 12423...
# 10  5.683198e+06  [12499.060638330988, 12499.063827674741, 12499...
# 11  5.566090e+06  [12668.91438981977, 12668.124854753665, 12626....
# 12  7.648743e+06  [12668.91438981977, 12674.94419368116, 12674.6...
# 13  5.851132e+06  [12486.163329241215, 12486.162990066054, 12481...
# 14  4.554841e+06  [12833.385861673749, 12831.358653723166, 12822...
# 15  4.301750e+06  [12543.135440504588, 12459.663895941238, 12384...
# 16  7.516239e+06  [12486.163329241215, 12481.868142346457, 12481...
# 17  4.751765e+06  [12668.91438981977, 12613.365621742616, 12545....
# 18  4.301720e+06  [12543.135440504588, 12459.663895941238, 12384...
# 19  5.625435e+06  [12668.91438981977, 12658.844187297844, 12617....
# 20  6.015328e+06  [12668.91438981977, 12675.561158267103, 12681....
# 21  4.849121e+06  [12499.060638330988, 12472.535659107947, 12472...
# 22  7.543685e+06  [12668.91438981977, 12674.94419368116, 12674.6...
# 23  5.522925e+06  [12833.385861673749, 12668.865207407902, 12644...
# 24  7.903642e+06  [12833.385861673749, 12833.385455500184, 12833...
# 25  5.596055e+06  [12486.163329241215, 12453.460656928773, 12357...
# 26  7.644220e+06  [12499.060638330988, 12499.063827674741, 12499...
# 27  4.848535e+06  [12499.060638330988, 12472.535659107947, 12472...
# 28  4.751770e+06  [12668.91438981977, 12613.365621742616, 12545....
# 29  5.400356e+06  [12833.385861673749, 12786.079063427167, 12719...
# 7                     bald  bcab2_00002
# 8                   greedy  bcab2_00013
# 9        thompson_sampling  bcab2_00019
# 10    expected_improvement  bcab2_00005
# 11       thompson_sampling  bcab2_00016
# 12  upper_confidence_bound  bcab2_00021
# 13    expected_improvement  bcab2_00008
# 14      variance_reduction  bcab2_00027
# 15                    bald  bcab2_00004
# 16  upper_confidence_bound  bcab2_00023
# 17                    bald  bcab2_00001
# 18      variance_reduction  bcab2_00029
# 19                  random  bcab2_00031
# 20    expected_improvement  bcab2_00006
# 21      variance_reduction  bcab2_00025
# 22                  greedy  bcab2_00011
# 23                  random  bcab2_00032
# 24  upper_confidence_bound  bcab2_00022
# 25       thompson_sampling  bcab2_00018
# 26                  greedy  bcab2_00010
# 27                    bald  bcab2_00000
# 28      variance_reduction  bcab2_00026
# 29       thompson_sampling  bcab2_00017
# 30    expected_improvement  bcab2_00007
# 31                  random  bcab2_00030

# %%
from tqdm import tqdm
def process_results_grid_into_sns_plot_df(results_df):
    """Process the results grid into a data frame so that we can plot line plots with seaborn.

    The current results_df format has each row as a trial, with columns for the trial's parameters and metrics.
    We want to create a data frame that has a row for each trial and each element in the list of iteration_metrics,
    such that we can plot the metrics over the iterations. The resulting data frame will have the following columns:

    - trial_id: The trial's ID
    - iteration: The iteration number
    - test_metric: The test metric at that iteration
    - strategy: The strategy used in that iteration
    - seed: The seed used in that trial
    - score: The score for that trial
    """

    # iteration_metrics = ["test_metric"] # if it was a dictionary entry in the row
    sns_plot_df = []

    for a, row in tqdm(results_df.iterrows()):
        trial_id = row["trial_id"]
        seed = row["config/seed"]
        score = row["score"]

        for iteration, metric_value in enumerate(row["iteration_metrics"]):
            # for metric_val in iteration_metrics:
            sns_plot_df.append(
                {
                    "trial_id": trial_id,
                    "iteration": iteration,
                    "test_metric": metric_value,
                    "strategy": row["config/strategy"],
                    "seed": seed,
                    "score": score,
                }
            )

    return pd.DataFrame(sns_plot_df)

# %%
sns_results_df = process_results_grid_into_sns_plot_df(results_df)
sns_results_df
# Out:
# 32it [00:00, 1187.95it/s]
#           trial_id  iteration   test_metric strategy  seed         score
# 0      bcab2_00034          0  12543.135441   random     5  5.166459e+06
# 1      bcab2_00034          1  12544.588570   random     5  5.166459e+06
# 2      bcab2_00034          2  12502.373160   random     5  5.166459e+06
# 3      bcab2_00034          3  12499.449991   random     5  5.166459e+06
# 4      bcab2_00034          4  12500.733661   random     5  5.166459e+06
# ...            ...        ...           ...      ...   ...           ...
# 28827  bcab2_00030        896   3429.152775   random     1  5.610504e+06
# 28828  bcab2_00030        897   3427.021629   random     1  5.610504e+06
# 28829  bcab2_00030        898   3427.020174   random     1  5.610504e+06
# 28830  bcab2_00030        899   3425.064273   random     1  5.610504e+06
# 28831  bcab2_00030        900   3425.091385   random     1  5.610504e+06
#
# [28832 rows x 6 columns]

# %%
sns.lineplot(data=sns_results_df, x="iteration", y="test_metric", hue="strategy")
# Out:
# <Axes: xlabel='iteration', ylabel='test_metric'>
